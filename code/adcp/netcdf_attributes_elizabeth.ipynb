# %% [markdown]
# #### Imports

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import gvpy as gv
# %reload_ext autoreload
# %autoreload 2
plt.ion()
# %config InlineBackend.figure_format = 'retina'

# %%
nc = xr.open_dataset('example_netcdf/PISTON-uctd_RV-Thompson_20180823_R0_thru_20180916.nc')

# %%
nc
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 253, depth: 398)
# Coordinates:
#   * time     (time) datetime64[ns] 2018-08-23T05:41:08.000004440 ... 2018-09-...
#   * depth    (depth) float64 3.0 4.0 5.0 6.0 7.0 ... 397.0 398.0 399.0 400.0
# Data variables:
#     lat      (time) float64 ...
#     lon      (time) float64 ...
#     c        (depth, time) float64 ...
#     p        (depth, time) float64 ...
#     t        (depth, time) float64 ...
#     s        (depth, time) float64 ...
#     sig      (depth, time) float64 ...
# Attributes: (12/23)
#     title:                      PISTON 2018 uCTD profiles of the upper ocean ...
#     project:                    PISTON, Propagation of Intraseasonal Summer T...
#     funding:                    NOAA Climate Program Office Climate Variabilt...
#     version:                    R0
#     institution:                Scripps Institution of Oceanography, SIO
#     author:                     Janet Sprintall
#     ...                         ...
#     sea_name:                   Pacific
#     ship:                       data collected from aboard the R/V Thomas G. ...
#     keywords_vocabulary:        NASA Global Change Master Directory (GCMD) Sc...
#     standard_name_vocabulary:   NetCDF Climate and Forecast (CF) Metadata Con...
#     geospatial_lat_units:       degree_north
#     geospatial_lon_units:       degree_east
